# %% [markdown]
# ### API
# In the previous notebook I worked with APIs and in this notebook I want to
# work with APIs again to learn how to work with them better. I'm going to
# use an API that gives me random phtots of cats and another one that gives
# information on sunset and sunrise times.

# %% [markdown]
# In the next cell I will try to see if I can retrieve data or not.

# %%
import requests
url = "https://cataas.com/cat"
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# Code 200 means that the request was successful.
# Now we will trun it into a dictionary using Json moduke

# %%
response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File E:\Anaconda\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File E:\Anaconda\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %% [markdown]
# So it gave me an error. let's see what is in this response.

# %%
response.content
# Out:
# b'\xff\xd8\xff\xdb\x00C\x00\x06\x04\x05\x06\x05\x04\x06\x06\x05\x06\x07\x07\x06\x08\n\x10\n\n\t\t\n\x14\x0e\x0f\x0c\x10\x17\x14\x18\x18\x17\x14\x16\x16\x1a\x1d%\x1f\x1a\x1b#\x1c\x16\x16 , #&\')*)\x19\x1f-0-(0%()(\xff\xdb\x00C\x01\x07\x07\x07\n\x08\n\x13\n\n\x13(\x1a\x16\x1a((((((((((((((((((((((((((((((((((((((((((((((((((\xff\xc0\x00\x11\x08\x02\x15\x03 \x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x01\x05\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x00\x01\x03\x04\x05\x06\x07\x08\xff\xc4\x008\x10\x00\x02\x01\x03\x03\x04\x02\x00\x04\x06\x02\x01\x04\x02\x03\x00\x00\x01\x02\x03\x04\x11\x12!1\x05AQa\x13"\x06\x142q#BR\x81\x91\xa1b\xb1\x15\x07$3\xc1C\xd1cr\x82\xff\xc4\x00\x19\x01\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\xff\xc4\x00%\x11\x01\x01\x01\x01\x00\x03\x01\x00\x02\x02\x03\x01\x01\x01\x00\x00\x00\x01\x11\x02\x03!1\x12AQ\x13"\x042aq\x14B\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xd4\xd7\xe0wS\x1c\
# ...

# %% [markdown]
# Maybe it's an image url.

# %%
from IPython.display import Image,display 
image_url=response.content
display(Image(image_url))

# %% [markdown]
# So the response was neither a text or a dictionary. It was an image url.
